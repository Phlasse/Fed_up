# %% [markdown]
# # At the subscription

# %% [markdown]
# ## User profile

# %% [markdown]
# **Goal:** The user must define his/her profile.

# %% [markdown]
# - **Gender**: the user chooses between: **male / female**
# - **Age**: the user fills a number or selects one in drop-down list?
# - **Height**: the user fills a number
# - **Weight**: the user fills a number
# - **Diet**: the user chooses between **Lose weight / maintain weight / build muscle**
# - **Activity level**: the user chooses between **sedentary / low / moderate / high**

# %% [markdown]
# ### ❓Questions

# %% [markdown]
# - Should we ask the user his preferences regarding the units? **Imperial** (pounds/feets) or **metric** (kg/m)
# - Should the user set a goal weight?

# %% [markdown]
# ## User preferences (Static Preferences)

# %% [markdown]
# - All the preferences set by the user must filter the database.
# - Those preferences can be changed in the `settings`.
# - Fed Up provides predefined tags and the user just has to click on it. We can also provide a search bar to allow the user to search one special iteam.
#
# The categories come from Meanlime. If you are **vegan** in the `1.2.1 Diet`, Fed Up won't suggest **Fish** or **Egg** in `1.2.2 Allergies` neither in `1.2.3 Dislikes`

# %% [markdown]
# ### Diet

# %% [markdown]
# - **Classic**
# - **Low Carb**
# - **Flexitarian:** easy on meat
# - **Vegetarian:** zero meat
# - **Pescetarian:** vegetarian + seafood
# - **Vegan:** only plants
#
# Just one click by the user.

# %% [markdown]
# ### Allergies

# %% [markdown]
# - Shellfish
# - Fish
# - Gluten
# - Peanut
# - Dairy
# - Tree nut
# - Soy
# - Egg
# - Sesame
# - Mustard
# - Sulfite
# - Nightshade
#
# The user can select more than 1 tag and can look for an item in a search bar.

# %% [markdown]
# ### Dislikes

# %% [markdown]
# - Avocado
# - Beef
# - Beets
# - Bell peppers
# - Blue cheese
# - Brussels sprouts
# - Cauliflower
# - Eggplant
# - Eggs
# - Goat cheese
# - Lamb
# - Mushrooms
# - Olives
# - Pork
# - Quinoa
# - Salmon
# - Shrimp
# - Tofu
# - Tuna
#
# The user can select more than 1 tag and can look for an item in a search bar.

# %% [markdown]
# # At any login on *Fed Up!* app (Dynamic Preferences)

# %% [markdown]
# **Goal:** Get the recommendation for the planning

# %% [markdown]
# ## How many days?

# %% [markdown]
# - Drop-down list with 3-days by default

# %% [markdown]
# ## Courses

# %% [markdown]
# - Breakfast
# - Lunch
# - Dinners

# %% [markdown]
# ## Time

# %% [markdown]
# - Up to 15min
# - Up to 30min
# - Up to 45min
# - Up to 1h
# - More than 1h

# %% [markdown]
# ## How many servings?

# %% [markdown]
# - 1 serving
# - 2 servings (for two, or one with leftlovers)
# - 4 servings
# - 6 servings

# %% [markdown]
# ## Recipes

# %% [markdown]
# - New things and different ingredients
# - Familiar and family-friendly flavors

# %% [markdown]
# # Nutritional Rules to achieve your goals

# %% [markdown]
# ## How many calories to consume each day?

# %% [markdown]
# ### Caculate the calorie needs

# %% [markdown]
# - **Men:** $calories/day = 10 \times \ weight (kg) + 6.25 \times \ height (cm) – 5 \times \ age (y) + 5$
#
#
# - **Women:** $calories/day = 10 \times\ weight (kg) + 6.25 \times \ height (cm) – 5 \times \ age (y) – 161$

# %% [markdown]
# ### Multiply the calorie needs by the activity factor to get the TDEE

# %% [markdown]
# |Activity|Factor|
# |-----|-------|
# |Sedentary|1.2|
# |Low|1.375|
# |Moderate|1.55|
# |High|1.725|

# %% [markdown]
# ## Macronutrient Breakdown

# %% [markdown]
# |Diet|Default|Low Carb|Low Fat|High Proteins|
# |-------|-------|-------|-------|-------|
# |Goal|Maintain Weight|Lose Weight|Obesity|Build Muscles|
# |Carb|50%|30%|55%|35%|
# |Proteins|20%|25%|20%|40%|
# |Fat|30%|45%|25%|25%|

# %%
cd Fed_up
# Out:
# /home/olivier/code/Phlasse/Fed_up/Fed_up

# %%
ls
# Out:
# data/  __init__.py  model.py  __pycache__/  recipe.py  review.py  utils.py

# %%
from Fed_up.recipe import clean_data, get_data, get_raw_data, select_universe
import pandas as pd

# %% [markdown]
# ## Loading initial Data not clean

# %%
#recipe_df = clean_data(select_universe(get_raw_data()))

# %% [markdown]
# ## Loading "Preprocessed" Data

# %%
recipe_df = pd.read_csv('../Fed_up/data/raw/data_preprocessed_recipe_pp_20201117_1347.csv')

# %%
recipe_df.shape
# Out:
# (181874, 21)

# %%
recipe_df.columns
# Out:
# Index(['recipe_id', 'user_id', 'name', 'rating_mean', 'rating_count',
#        'minutes', 'n_steps', 'n_ingredients', 'calories', 'total_fat', 'sugar',
#        'sodium', 'protein', 'saturated_fat', 'carbohydrates', 'tags',
#        'ingredients', 'steps', 'description', 'metadata', 'submitted'],
#       dtype='object')

# %%
macro_list = ['recipe_id', 'name', 'calories', 'total_fat', 'sugar', 'protein', 'saturated_fat', 'carbohydrates']

# %%
recipe_df[macro_list].head(25)
# Out:
#     recipe_id                                          name  calories  \
# 0      137739    arriba   baked winter squash mexican style      51.5
# 1       31490              a bit different  breakfast pizza     173.4
# 2      112140                     all in the kitchen  chili     269.8
# 3       59389                            alouette  potatoes     368.1
# 4       44061            amish  tomato ketchup  for canning     352.9
# 5       25274                         aww  marinated olives     380.7
# 6       75452                       beat this  banana bread    2669.3
# 7       43026                                chile rellenos      94.0
# 8       23933                                chinese  candy     232.7
# 9        8559                            chinese  chop suey     395.4
# 10      23850             cream  of cauliflower soup  vegan     174.2
# 11      76808                        cream  of spinach soup     126.0
# 12      24701                 cream  of spinach soup  vegan      64.8
# 13      83873                       crispy crunchy  chicken     335.8
# 14      49262               easiest ever  hollandaise sauce    1290.4
# 15      48156              emotional balance  spice mixture     182.7
# 16      54272                   fool the meat eaters  chili     295.6
# 17      37073                               fried  potatoes     132.6
# 18      44123         george s at the cove  black bean soup     804.7
# 19      27087                   get the sensation  brownies     174.4
# 20      59952                global gourmet  taco casserole     456.8
# 21      93249                          grilled  ranch bread    1649.8
# 22      54100                      grilled  venison burgers     190.9
# 23      87098           homemade  vegetable soup from a can     276.2
# 24      22123  i don t feel like cooking tonight  casserole     647.6
#
#     total_fat  sugar  protein  saturated_fat  carbohydrates
# 0         0.0   13.0      2.0            0.0            4.0
# 1        18.0    0.0     22.0           35.0            1.0
# 2        22.0   32.0     39.0           27.0            5.0
# 3        17.0   10.0     14.0            8.0           20.0
# 4         1.0  337.0      3.0            0.0           28.0
# 5        53.0    7.0      6.0           24.0            6.0
# 6       160.0  976.0     62.0          310.0          138.0
# 7        10.0    0.0     11.0           21.0            0.0
# 8        21.0   77.0      6.0           38.0            8.0
# 9        31.0   20.0     51.0           33.0            8.0
# 10        4.0   24.0     15.0            1.0           10.0
# 11       11.0    2.0      5.0           23.0            4.0
# 12        3.0   13.0      4.0            2.0            3.0
# 13       11.0    2.0     64.0           10.0           10.0
# 14      213.0    4.0     22.0          417.0            1.0
# 15       11.0    4.0     13.0            4.0           10.0
# 16        3.0   56.0     32.0            1.0           18.0
# 17        8.0    4.0      4.0            5.0            6.0
# 18      108.0   26.0     28.0          214.0           10.0
# 19       13.0   67.0      4.0           26.0            7.0
# 20       40.0   34.0     57.0           51.0            9.0
# 21       91.0    4.0     80.0          160.0           78.0
# 22       10.0   10.0     45.0           15.0            2.0
# 23        3.0   55.0     23.0            2.0           20.0
# 24       57.0   57.0     54.0           53.0           16.0

# %% [markdown]
# |Diet|Default|Low Carb|Low Fat|High Proteins|
# |-------|-------|-------|-------|-------|
# |Goal|Maintain Weight|Lose Weight|Gain Weight|Build Muscles|
# |Carb|50%|30%|55%|35%|
# |Proteins|20%|25%|20%|40%|
# |Fat|30%|45%|25%|25%|

# %%
goals = ['maintain', 'lose', 'gain', 'build']

# %%
def goals_filter(df, goal):
    goals = {
        'maintain': { 'carb': 50.0, 'protein': 20.0, 'fat': 30.0},
        'lose': {'carb': 30.0, 'protein': 25.0, 'fat': 45.0},
        'gain': {'carb': 55.0, 'protein': 20.0, 'fat': 25.0},
        'build': {'carb': 35.0, 'protein': 40.0, 'fat': 25.0}
    }
    filter_df = df.copy()
    
    ## Filtering on : 
    ## 1. Goals percentage for one day intake divided by 3 => Assuming a meal
    ## 2. Then take recipe with a range of -10% and +10% of each macronutriment for each goal
    carb_filter = (filter_df['carbohydrates'] > ((goals[goal]['carb']/3) - 10.0)) & (filter_df['carbohydrates'] < (goals[goal]['carb']/3 + 10.0))
    protein_filter = (filter_df['protein'] > (goals[goal]['protein']/3 - 10.0)) & (filter_df['protein'] < (goals[goal]['protein']/3 + 10.0))
    fat_filter = (filter_df['total_fat'] > (goals[goal]['fat']/3 - 10.0)) & (filter_df['total_fat'] < (goals[goal]['fat']/3 + 10.0))
    
    return filter_df[carb_filter & protein_filter & fat_filter]

# %%
from IPython.display import display

# %%
print(f"Initial DataFrame Shape : {recipe_df.shape}")
print("")
x =20

for goal in goals:
    print(f"################# {goal.capitalize()} #################")
    print(f"Shape after filtering : {goals_filter(recipe_df, goal)[macro_list].shape}")
    print(f"Showing {x} first values of filtered DataFrame : ")
    display(goals_filter(recipe_df, goal)[macro_list].head(x))
# Out:
# Initial DataFrame Shape : (181874, 21)
#
# ################# Maintain #################
# Shape after filtering : (22811, 8)
# Showing 20 first values of filtered DataFrame :
#      recipe_id                                          name  calories  \
# 3        59389                            alouette  potatoes     368.1
# 10       23850             cream  of cauliflower soup  vegan     174.2
# 15       48156              emotional balance  spice mixture     182.7
# 19       27087                   get the sensation  brownies     174.4
# 26       93958                     i yam what i yam  muffins     171.8
# 29       94710                                italian  fries     241.0
# 38       35653                  make it your way  shortcakes     175.2
# 57       95926                    say what   banana sandwich     238.0
# 64       83133             stove top  bbq  beef or pork ribs     179.3
# 67       39363            the best  banana bread  or muffins     175.7
# 70       61973                       to your health  muffins     159.0
# 74       70099                          1 asian noodle salad     231.1
# 101     149593                      add in anything  muffins     209.3
# 103     100540               almost grilled  cheese sandwich     195.3
# 109     325509                   berry french toast  oatmeal     190.9
# 130     343338               creamy   vegan potato leek soup     183.0
# 138     176717                   fake   blueberry cheesecake     328.4
# 152      32363  homebakes   knock off beef stew and biscuits     191.9
# 153     235173                           hot tamale  burgers     165.3
# 159     270259    joe s  peppermint cookies n cream brownies     185.5
#
#      total_fat  sugar  protein  saturated_fat  carbohydrates
# 3         17.0   10.0     14.0            8.0           20.0
# 10         4.0   24.0     15.0            1.0           10.0
# 15        11.0    4.0     13.0            4.0           10.0
# 19        13.0   67.0      4.0           26.0            7.0
# 26         9.0   28.0      8.0            4.0            8.0
# 29        12.0    1.0     10.0           11.0           12.0
# 38        11.0   15.0      7.0           21.0            7.0
# 57         3.0   66.0     10.0            2.0           17.0
# 64         7.0  119.0      3.0            3.0           11.0
# 67         9.0   65.0      5.0           18.0            9.0
# 70         8.0   58.0      7.0            4.0            8.0
# 74         7.0   21.0      8.0            3.0           14.0
# 101       18.0   44.0      5.0           36.0            7.0
# 103        9.0   14.0     15.0           16.0            8.0
# 109        8.0    2.0     13.0            3.0            9.0
# 130        3.0   10.0     13.0            1.0           11.0
# 138       15.0  205.0      1.0           43.0           19.0
# 152       14.0    6.0      9.0           13.0            7.0
# 153        5.0    4.0      7.0            2.0           10.0
# 159       14.0   75.0      4.0           28.0            8.0
# ################# Lose #################
# Shape after filtering : (40241, 8)
# Showing 20 first values of filtered DataFrame :
#     recipe_id                                  name  calories  total_fat  \
# 8       23933                        chinese  candy     232.7       21.0
# 11      76808                cream  of spinach soup     126.0       11.0
# 15      48156      emotional balance  spice mixture     182.7       11.0
# 17      37073                       fried  potatoes     132.6        8.0
# 19      27087           get the sensation  brownies     174.4       13.0
# 26      93958             i yam what i yam  muffins     171.8        9.0
# 29      94710                        italian  fries     241.0       12.0
# 38      35653          make it your way  shortcakes     175.2       11.0
# 40      44045              mennonite  corn fritters      67.1        7.0
# 42      81185       mock a mole   low fat guacamole     115.9        7.0
# 60      41756   souper  easy sweet   sour meatballs     114.6        6.0
# 64      83133     stove top  bbq  beef or pork ribs     179.3        7.0
# 67      39363    the best  banana bread  or muffins     175.7        9.0
# 70      61973               to your health  muffins     159.0        8.0
# 71      58651                       turtle  squares     172.4       16.0
# 74      70099                  1 asian noodle salad     231.1        7.0
# 75     333281  1 brownies in the world    best ever     138.4       10.0
# 80      31835                     1 squash dressing     157.7       17.0
# 89     177187     250 chocolate chip cookies recipe     150.4       12.0
# 93      69190                     ara s potato  oup     346.7       21.0
#
#     sugar  protein  saturated_fat  carbohydrates
# 8    77.0      6.0           38.0            8.0
# 11    2.0      5.0           23.0            4.0
# 15    4.0     13.0            4.0           10.0
# 17    4.0      4.0            5.0            6.0
# 19   67.0      4.0           26.0            7.0
# 26   28.0      8.0            4.0            8.0
# 29    1.0     10.0           11.0           12.0
# 38   15.0      7.0           21.0            7.0
# 40    2.0      3.0           10.0            1.0
# 42   21.0      9.0            3.0            5.0
# 60   45.0     10.0            7.0            4.0
# 64  119.0      3.0            3.0           11.0
# 67   65.0      5.0           18.0            9.0
# 70   58.0      7.0            4.0            8.0
# 71   51.0      2.0           26.0            6.0
# 74   21.0      8.0            3.0           14.0
# 75   50.0      3.0           19.0            6.0
# 80   11.0     11.0           27.0            2.0
# 89   47.0      4.0           18.0            6.0
# 93   23.0     17.0           35.0           16.0
# ################# Gain #################
# Shape after filtering : (17957, 8)
# Showing 20 first values of filtered DataFrame :
#      recipe_id                                               name  calories  \
# 3        59389                                 alouette  potatoes     368.1
# 4        44061                 amish  tomato ketchup  for canning     352.9
# 10       23850                  cream  of cauliflower soup  vegan     174.2
# 15       48156                   emotional balance  spice mixture     182.7
# 29       94710                                     italian  fries     241.0
# 55       19208                                red hot  applesauce     110.1
# 57       95926                         say what   banana sandwich     238.0
# 64       83133                  stove top  bbq  beef or pork ribs     179.3
# 65       39947                                     sugared grapes     140.4
# 67       39363                 the best  banana bread  or muffins     175.7
# 74       70099                               1 asian noodle salad     231.1
# 100     495314                           go to bbq sauce for ribs     233.5
# 109     325509                        berry french toast  oatmeal     190.9
# 130     343338                    creamy   vegan potato leek soup     183.0
# 138     176717                        fake   blueberry cheesecake     328.4
# 153     235173                                hot tamale  burgers     165.3
# 174     179640                          man  rice krispies treats     265.2
# 179     293836                     near east  rice pilaf  low fat     236.9
# 192     197001  pink stuff     cherry pie filling  pineapple d...     338.9
# 195     354039       quick and healthy picker uppers apple treats     222.2
#
#      total_fat  sugar  protein  saturated_fat  carbohydrates
# 3         17.0   10.0     14.0            8.0           20.0
# 4          1.0  337.0      3.0            0.0           28.0
# 10         4.0   24.0     15.0            1.0           10.0
# 15        11.0    4.0     13.0            4.0           10.0
# 29        12.0    1.0     10.0           11.0           12.0
# 55         0.0   91.0      1.0            0.0            9.0
# 57         3.0   66.0     10.0            2.0           17.0
# 64         7.0  119.0      3.0            3.0           11.0
# 65         0.0  133.0      4.0            0.0           11.0
# 67         9.0   65.0      5.0           18.0            9.0
# 74         7.0   21.0      8.0            3.0           14.0
# 100        0.0  209.0      2.0            0.0           19.0
# 109        8.0    2.0     13.0            3.0            9.0
# 130        3.0   10.0     13.0            1.0           11.0
# 138       15.0  205.0      1.0           43.0           19.0
# 153        5.0    4.0      7.0            2.0           10.0
# 174        8.0  112.0      4.0           16.0           17.0
# 179        3.0    1.0     10.0            1.0           15.0
# 192       18.0  150.0      8.0           48.0           18.0
# 195        5.0  108.0      7.0            5.0           15.0
# ################# Build #################
# Shape after filtering : (37662, 8)
# Showing 20 first values of filtered DataFrame :
#     recipe_id                                 name  calories  total_fat  \
# 3       59389                   alouette  potatoes     368.1       17.0
# 10      23850    cream  of cauliflower soup  vegan     174.2        4.0
# 11      76808               cream  of spinach soup     126.0       11.0
# 12      24701        cream  of spinach soup  vegan      64.8        3.0
# 15      48156     emotional balance  spice mixture     182.7       11.0
# 17      37073                      fried  potatoes     132.6        8.0
# 19      27087          get the sensation  brownies     174.4       13.0
# 23      87098  homemade  vegetable soup from a can     276.2        3.0
# 26      93958            i yam what i yam  muffins     171.8        9.0
# 28      33606        italian sandwich  pasta salad     279.2       14.0
# 29      94710                       italian  fries     241.0       12.0
# 38      35653         make it your way  shortcakes     175.2       11.0
# 42      81185      mock a mole   low fat guacamole     115.9        7.0
# 57      95926           say what   banana sandwich     238.0        3.0
# 60      41756  souper  easy sweet   sour meatballs     114.6        6.0
# 65      39947                       sugared grapes     140.4        0.0
# 67      39363   the best  banana bread  or muffins     175.7        9.0
# 70      61973              to your health  muffins     159.0        8.0
# 74      70099                 1 asian noodle salad     231.1        7.0
# 80      31835                    1 squash dressing     157.7       17.0
#
#     sugar  protein  saturated_fat  carbohydrates
# 3    10.0     14.0            8.0           20.0
# 10   24.0     15.0            1.0           10.0
# 11    2.0      5.0           23.0            4.0
# 12   13.0      4.0            2.0            3.0
# 15    4.0     13.0            4.0           10.0
# 17    4.0      4.0            5.0            6.0
# 19   67.0      4.0           26.0            7.0
# 23   55.0     23.0            2.0           20.0
# 26   28.0      8.0            4.0            8.0
# 28   12.0     23.0           11.0           12.0
# 29    1.0     10.0           11.0           12.0
# 38   15.0      7.0           21.0            7.0
# 42   21.0      9.0            3.0            5.0
# 57   66.0     10.0            2.0           17.0
# 60   45.0     10.0            7.0            4.0
# 65  133.0      4.0            0.0           11.0
# 67   65.0      5.0           18.0            9.0
# 70   58.0      7.0            4.0            8.0
# 74   21.0      8.0            3.0           14.0
# 80   11.0     11.0           27.0            2.0
