# %%
import pandas as pd

# %%
# !ls
# Out:
# Untitled.ipynb              review_pp_20201117_1347.csv
# recipe_pp_20201117_1347.csv

# %%
recipes = pd.read_csv('recipe_pp_20201117_1347.csv')

# %%
recipes.head()
# Out:
#    recipe_id  user_id                                        name  \
# 0     137739    47892  arriba   baked winter squash mexican style
# 1      31490    26278            a bit different  breakfast pizza
# 2     112140   196586                   all in the kitchen  chili
# 3      59389    68585                          alouette  potatoes
# 4      44061    41706          amish  tomato ketchup  for canning
#
#    rating_mean  rating_count  minutes  n_steps  n_ingredients  calories  \
# 0          5.0             3       55       11              7      51.5
# 1          3.5             4       30        9              6     173.4
# 2          4.0             1      130        6             13     269.8
# 3          4.5             2       45       11             11     368.1
# 4          5.0             1      190        5              8     352.9
#
#    total_fat  ...  sodium  protein  saturated_fat  carbohydrates  \
# 0        0.0  ...     0.0      2.0            0.0            4.0
# ...

# %%
recipes.shape
# Out:
# (181874, 21)

# %%
reviews = pd.read_csv('review_pp_20201117_1347.csv')

# %%
reviews.head()
# Out:
#    recipe_id     user_id  rating  liked  \
# 0     120345       52282       4      1
# 1     120345      124416       0      0
# 2     120345  2000192946       2      0
# 3     134728       76535       4      1
# 4     134728      273745       5      1
#
#                                               review        date
# 0  very very sweet. after i waited the 2 days i b...  2005-05-21
# 1  Just an observation, so I will not rate.  I fo...  2011-08-06
# 2  This recipe was OVERLY too sweet.  I would sta...  2015-05-10
# 3                                         Very good!  2005-09-02
# 4                             Better than the real!!  2005-12-22

# %%
reviews.shape
# Out:
# (901746, 6)
