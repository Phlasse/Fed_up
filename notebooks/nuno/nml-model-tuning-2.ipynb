# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
from Fed_up import test

# %% [markdown]
# # Auto-Analysis

# %%
vectorizors = ['count', 'tfidf']
redutors = ['svd', 'nmf']

# %%
outputs = pd.DataFrame(columns=['vectorizor', 'redutor', 'ngram', 'min_df', 'max_df', 
                                'rating_mae', 'rating_le', 'like_accuracy', 'like_precision', 
                                'like_recall', 'like_f1', 'size', 'time'])

# %%
# Baseline

start = time.time()
data, metrics = test.run_test(predict = False, sample = 200, local=True)
end = time.time()
duration = end - start

new_row = {'vectorizor': '-', 'redutor': '-', 'ngram': '-', 'min_df': '-', 'max_df': '-', 
           'rating_mae': metrics['rating_mae'], 'rating_le': metrics['rating_le'], 
           'like_accuracy': metrics['like_accuracy'], 'like_precision': metrics['like_precision'], 
           'like_recall': metrics['like_recall'], 'like_f1': metrics['like_f1'], 
           'size': len(data), 'time': duration}

outputs = outputs.append(new_row, ignore_index=True)
# Out:
# Fetching the test inputs...
# Calculating predictions...
# Preparing results dataframe...
# Cleaning up failed scores...
# Iterating and filling results dataframe...
# Saving results dataframe...
# Calculating metrics for tests...

# %%
outputs
# Out:
#   vectorizor redutor ngram min_df max_df  rating_mae  rating_le  \
# 0          -       -     -      -      -        0.53       0.05
#
#    like_accuracy  like_precision  like_recall  like_f1 size      time
# 0           0.88           0.936        0.936    0.936  200  0.234074

# %%
import time

for v in vectorizors:
    for r in redutors:
            
        start = time.time()
        data, metrics = test.run_test(sample = 50, vectorizer = v, dimred = r)
        end = time.time()
        duration = end - start

        new_row = {'vectorizor': v, 'redutor': r, 'ngram': (1,1), 'min_df': 1, 'max_df': 1.0, 
                   'rating_mae': metrics['rating_mae'], 'rating_le': metrics['rating_le'], 
                   'like_accuracy': metrics['like_accuracy'], 'like_precision': metrics['like_precision'], 
                   'like_recall': metrics['like_recall'], 'like_f1': metrics['like_f1'], 
                   'size': len(data), 'time': duration}

        outputs = outputs.append(new_row, ignore_index=True)
        print("")
        display(outputs)
        print("")
# Out:
# Fetching the test inputs...
# Calculating predictions...
# > (12471) Prediction for user 375894 done: 0.749!
# > (19992) Prediction for user 831612 done: 0.576!
# > (25450) Prediction for user 1608793 done: 0.165!
# > (6494) Prediction for user 183942 done: 0.407!
# > (3265) Prediction for user 92295 done: 0.737!
# > (19949) Prediction for user 828089 done: 0.21!
# > (7085) Prediction for user 200171 done: 0.232!
# > (10341) Prediction for user 304561 done: 0.306!
# > (26205) Prediction for user 1813203 done: 0.385!
# > (11462) Prediction for user 343641 not found!
# > (24413) Prediction for user 1393592 done: 0.534!
# > (25873) Prediction for user 1698075 done: 0.384!
# > (3122) Prediction for user 88028 done: 0.364!
# > (16444) Prediction for user 578971 done: 0.521!
# > (27757) Prediction for user 1800310325 done: 0.427!
# > (7497) Prediction for user 212478 done: 0.456!
# > (17092) Prediction for user 616120 done: 0.185!
# > (12947) Prediction for user 400411 done: 0.271!
# ...

# %% [markdown]
# # Vectorizer vs. Dimred

# %%
start = time.time()
input_df, output_df = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'count', dimred = 'svd', ngram = (1,1), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.814424
# 1     255836                                  chicken parmigina  2.065884
# 2     411372                      caesar salad dressing  no egg  1.399572
# 3     281914               root vegetables casserole for winter  1.983682
# 4      76593  weymo s accelerated version of grannie s turke...  1.727159
# 5      51887             feta stuffed chicken with green olives  1.646257
# ...

# %%
start = time.time()
input_df_2, output_df_2 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.812720
# 1     255836                                  chicken parmigina  2.069633
# 2     411372                      caesar salad dressing  no egg  1.411734
# 3      76593  weymo s accelerated version of grannie s turke...  1.717885
# 4     281914               root vegetables casserole for winter  1.982042
# 5     197905           angel hair pasta with pesto and tomatoes  1.637881
# ...

# %%
start = time.time()
input_df_3, output_df_3 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'count', dimred = 'nmf', ngram = (1,1), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.804481
# 1     255836                                  chicken parmigina  2.068661
# 2     411372                      caesar salad dressing  no egg  1.419645
# 3     281914               root vegetables casserole for winter  1.983159
# 4      76593  weymo s accelerated version of grannie s turke...  1.724714
# 5      51887             feta stuffed chicken with green olives  1.634836
# ...

# %%
start = time.time()
input_df_4, output_df_4 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'nmf', ngram = (1,1), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.803370
# 1     255836                                  chicken parmigina  2.077483
# 2     411372                      caesar salad dressing  no egg  1.410990
# 3     281914               root vegetables casserole for winter  1.970942
# 4      76593  weymo s accelerated version of grannie s turke...  1.712338
# 5     238415                chicken and rosemary cream rigatoni  1.631536
# ...

# %% [markdown]
# # Optimizing

# %%
start = time.time()
input_df_2, output_df_2 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.799415
# 1     255836                                  chicken parmigina  2.068178
# 2     411372                      caesar salad dressing  no egg  1.405879
# 3      76593  weymo s accelerated version of grannie s turke...  1.724876
# 4     281914               root vegetables casserole for winter  1.996500
# 5      51887             feta stuffed chicken with green olives  1.639412
# ...

# %% [markdown]
# ## Ngrams

# %%
start = time.time()
input_df_2_1, output_df_2_1 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,2), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.815435
# 1     255836                                  chicken parmigina  2.072711
# 2     411372                      caesar salad dressing  no egg  1.405543
# 3     281914               root vegetables casserole for winter  1.993451
# 4      76593  weymo s accelerated version of grannie s turke...  1.720469
# 5      51887             feta stuffed chicken with green olives  1.637296
# ...

# %%
start = time.time()
input_df_2_2, output_df_2_2 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (2,2), min_df = 1, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.799730
# 1     255836                                  chicken parmigina  2.070185
# 2     411372                      caesar salad dressing  no egg  1.411464
# 3      76593  weymo s accelerated version of grannie s turke...  1.724430
# 4     281914               root vegetables casserole for winter  1.985222
# 5      51887             feta stuffed chicken with green olives  1.634072
# ...

# %%
start = time.time()
input_df_2_3, output_df_2_3 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 0.10, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.803077
# 1     255836                                  chicken parmigina  2.082194
# 2     411372                      caesar salad dressing  no egg  1.410214
# 3     281914               root vegetables casserole for winter  1.982024
# 4      76593  weymo s accelerated version of grannie s turke...  1.722312
# 5     238415                chicken and rosemary cream rigatoni  1.634607
# ...

# %%
start = time.time()
input_df_2_3, output_df_2_3 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 0.20, max_df = 1.0, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.799785
# 1     255836                                  chicken parmigina  2.083157
# 2     411372                      caesar salad dressing  no egg  1.407436
# 3      76593  weymo s accelerated version of grannie s turke...  1.720726
# 4     281914               root vegetables casserole for winter  1.988745
# 5     238415                chicken and rosemary cream rigatoni  1.633033
# ...

# %%
start = time.time()
input_df_2_4, output_df_2_4 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 1, max_df = 0.9, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.800800
# 1     255836                                  chicken parmigina  2.076507
# 2     411372                      caesar salad dressing  no egg  1.411415
# 3      76593  weymo s accelerated version of grannie s turke...  1.721827
# 4     281914               root vegetables casserole for winter  1.982925
# 5     238415                chicken and rosemary cream rigatoni  1.638573
# ...

# %%
start = time.time()
input_df_2_5, output_df_2_5 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 1, max_df = 0.8, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.815288
# 1     255836                                  chicken parmigina  2.066436
# 2     411372                      caesar salad dressing  no egg  1.420445
# 3      76593  weymo s accelerated version of grannie s turke...  1.719828
# 4     281914               root vegetables casserole for winter  1.988369
# 5      51887             feta stuffed chicken with green olives  1.646730
# ...

# %%
start = time.time()
input_df_2_6, output_df_2_6 = test.run_recommendations(user_id=235291, collaborative=0.5, clear_neg=False,
                    vectorizer = 'tfidf', dimred = 'svd', ngram = (1,1), min_df = 0.1, max_df = 0.9, local = True)
end = time.time()
duration = end - start
print(duration)
# Out:
#   recipe_id                               name liked
# 0     16741             aunt bee s lentil soup     1
# 1     10744          delicious chicken pot pie     1
# 2     16575  just the best barbecue sauce ever     0
# 3     22782   jo mama s world famous spaghetti     1
# 4    107997       4 minute spicy garlic shrimp     1
# 5    212500               mushroom noodle soup     1
# 6    208930             mary s chiles rellenos     1
#    recipe_id                                               name   content  \
# 0     383814                                baked cod casserole  1.800870
# 1     255836                                  chicken parmigina  2.072898
# 2     411372                      caesar salad dressing  no egg  1.407657
# 3     281914               root vegetables casserole for winter  1.981748
# 4      76593  weymo s accelerated version of grannie s turke...  1.706253
# 5     277802                      zingy salsa chicken casserole  2.274460
# ...
